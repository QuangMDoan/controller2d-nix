# %%
import numpy as np 
import matplotlib.pyplot as plt 
from scipy.stats import multivariate_normal

mu = np.array([0, 5])
covariance = np.array([[0.01, 0], [0, 1]])
xk = np.random.multivariate_normal(mu, covariance)
print(xk)
dt = 0.5 
uk = -2 
yk = np.pi/6 
S = 20
D = 40
# Out:
# [[0.00742202 4.16823415]]
