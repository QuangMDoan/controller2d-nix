# %%
import numpy as np

p = 2*np.array([x for x in range(1, 6)])
p_dot = np.array([x for x in range(1, 6)])

print('p', p)
print('p_dot', p_dot)

data = np.array([p, p_dot])
print('data:', data)
# Out:
# p [ 2  4  6  8 10]
# p_dot [1 2 3 4 5]
# data: [[ 2  4  6  8 10]
#  [ 1  2  3  4  5]]
